# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
# Replace 'example.db' with your database file
connection = sqlite3.connect('../resources/rimusic_20241229182906.db')

# Query the database and load the data into a DataFrame
query = "SELECT * FROM Event"  # Replace table_name with your table
df = pd.read_sql_query(query, connection)
df

# Close the connection
connection.close()
# Out:
#           id       songId      timestamp  playTime
# 0          1  rbBbQ-jldvQ  1683257493946    170950
# 1          2  rbBbQ-jldvQ  1683257706634     87147
# 2          3  Pr3g9TPPuH4  1683257963584    256949
# 3          4  t2TKqJ2FXGM  1683258177324    213723
# 4          5  8kvb-pJEeEI  1683258328928    151593
# ...      ...          ...            ...       ...
# 43018  43019  2VPAdf9dkmQ  1735524998389    264362
# 43019  43020  EXmMiBNDVz4  1735525404879    369080
# 43020  43021  EXmMiBNDVz4  1735525404898    369080
# 43021  43022  xcprkHw4cd8  1735525599636    194747
# 43022  43023  xcprkHw4cd8  1735525599667    194747
#
# [43023 rows x 4 columns]
#           id       songId      timestamp  playTime
# 0          1  rbBbQ-jldvQ  1683257493946    170950
# 1          2  rbBbQ-jldvQ  1683257706634     87147
# 2          3  Pr3g9TPPuH4  1683257963584    256949
# 3          4  t2TKqJ2FXGM  1683258177324    213723
# 4          5  8kvb-pJEeEI  1683258328928    151593
# ...      ...          ...            ...       ...
# 43018  43019  2VPAdf9dkmQ  1735524998389    264362
# 43019  43020  EXmMiBNDVz4  1735525404879    369080
# 43020  43021  EXmMiBNDVz4  1735525404898    369080
# 43021  43022  xcprkHw4cd8  1735525599636    194747
# 43022  43023  xcprkHw4cd8  1735525599667    194747
#
# [43023 rows x 4 columns]

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
connection = sqlite3.connect('../resources/rimusic_20241229182906.db')

# Get the list of all tables
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql_query(tables_query, connection)

# Iterate through each table and print its contents
for table_name in tables['name']:
    print(f"Contents of table: {table_name}")
    table_data = pd.read_sql_query(f"SELECT * FROM {table_name};", connection)
    print(table_data)
    print("-" * 40)

# Close the connection
connection.close()
# Out:
# Contents of table: android_metadata
#   locale
# 0  en_US
# ----------------------------------------
# Contents of table: Song
#                id                               title    artistsText  \
# 0     rbBbQ-jldvQ                       Back To Black  Amy Winehouse
# 1     Pr3g9TPPuH4                You Know I'm No Good  Amy Winehouse
# 2     t2TKqJ2FXGM                               Rehab  Amy Winehouse
# 3     8kvb-pJEeEI                       Me & Mr Jones  Amy Winehouse
# 4     d1QltB3m0Hs              Tears Dry On Their Own  Amy Winehouse
# ...           ...                                 ...            ...
# 9989  k63KZROKk1w         e:HARDSTONE NATIONAL ANTHEM    Don Toliver
# 9990  mfRIXW9drHo                     e:ROCKSTAR GIRL    Don Toliver
# 9991  YDLGZCmO6us                    e:LOVE IS A DRUG    Don Toliver
# 9992  BTyzwZEVJe8  e:DONNY DARKO (feat. Lil Uzi Vert)    Don Toliver
# 9993  jbgsyvuXfxU            e:GEEKED UP (feat. Yeat)    Don Toliver
#
#      durationText                                       thumbnailUrl  likedAt  \
# 0            4:00  https://lh3.googleusercontent.com/HxwKiFSKsNLD...      NaN
# 1            4:16  https://lh3.googleusercontent.com/HxwKiFSKsNLD...      NaN
# 2            3:33  https://lh3.googleusercontent.com/HxwKiFSKsNLD...      NaN
# 3            2:31  https://lh3.googleusercontent.com/HxwKiFSKsNLD...      NaN
# 4            3:05  https://lh3.googleusercontent.com/HxwKiFSKsNLD...      NaN
# ...           ...                                                ...      ...
# 9989         2:42  https://lh3.googleusercontent.com/AT0wYoFYZ1K6...      NaN
# 9990         2:58  https://lh3.googleusercontent.com/AT0wYoFYZ1K6...      NaN
# 9991         3:09  https://lh3.googleusercontent.com/AT0wYoFYZ1K6...      NaN
# 9992         1:57  https://lh3.googleusercontent.com/AT0wYoFYZ1K6...      NaN
# 9993         2:38  https://lh3.googleusercontent.com/AT0wYoFYZ1K6...      NaN
#
#       totalPlayTimeMs
# 0            10544000
# 1            10030695
# 2             8276085
# 3             5246293
# 4             6443802
# ...               ...
# 9989                0
# 9990           369480
# 9991                0
# 9992                0
# 9993                0
#
# [9994 rows x 7 columns]
# ----------------------------------------
# Contents of table: SongPlaylistMap
#            songId  playlistId  position
# 0     1IKuVAGa4uI           5         1
# 1     KdtNE7yELtw           5         0
# 2     knfGe_qqqdU           5         2
# 3     fU-_4nEhqsg           5         3
# 4     yL0-bsU7OeU           5         4
# ...           ...         ...       ...
# 3763  o5El9mpHyeo          14       784
# 3764  DRiRCaFCzzU          14       785
# 3765  BNFRzCAqQbM          14       786
# 3766  34n7UTRu1Rs          14       787
# 3767  -etdkIwzZU0          14       788
#
# [3768 rows x 3 columns]
# ----------------------------------------
# Contents of table: Playlist
#    id                  name browseId
# 0   5  pinned:Teresa Teng++     None
# 1   6       monthly:2024-05     None
# 2   7       monthly:2024-06     None
# 3   9       monthly:2024-07     None
# 4  10       monthly:2024-08     None
# 5  11         pinned:Reggae     None
# 6  12       monthly:2024-09     None
# 7  13       monthly:2024-10     None
# 8  14       monthly:2024-11     None
# ----------------------------------------
# Contents of table: sqlite_sequence
#               name     seq
# 0      SearchQuery     765
# 1         Playlist      14
# 2            Event   43023
# 3  QueuedMediaItem  971609
# ----------------------------------------
# Contents of table: Artist
#                             id            name  \
# 0     UCMRsEwcN5cXdvqNP-UBup_A   Amy Winehouse
# 1     UCw8jIQzB2mdvvo_CVplLxug            Muse
# 2     UCQiH3xAP0i48o74BK6EBkMw      Eurythmics
# 3     UCcrR-Or3AH2RKJqOntiD_Tw           Gotye
# 4     UCA3Zs9A2IeetfGT3Omi9ivw          Hozier
# ...                        ...             ...
# 1047  UC-r6UYEn_VJTcSeHLo9kUYQ          Ro$ama
# 1048  UCmbsfE1vyuYRVzQHGZvvAvg        Lil Pump
# 1049  UCG8taJqKO1rskPEWcd4zIYA   Fivio Foreign
# 1050  UCPfrLj9H6OAn5NrTvsKuu2A      Gannondorf
# 1051  UCAdfsQUcrSMPn0TfNdRzQ9A  DB Tha General
#
#                                            thumbnailUrl     timestamp  \
# 0     https://lh3.googleusercontent.com/iH214983e5hb...  1.719722e+12
# 1                                                  None           NaN
# 2                                                  None           NaN
# 3                                                  None           NaN
# 4                                                  None           NaN
# ...                                                 ...           ...
# 1047                                               None           NaN
# 1048                                               None           NaN
# 1049  https://lh3.googleusercontent.com/5T62GBgZ7mNe...  1.735450e+12
# 1050                                               None           NaN
# 1051                                               None           NaN
#
#       bookmarkedAt
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 1047           NaN
# 1048           NaN
# 1049           NaN
# 1050           NaN
# 1051           NaN
#
# [1052 rows x 5 columns]
# ----------------------------------------
# Contents of table: SongArtistMap
#             songId                  artistId
# 0      rbBbQ-jldvQ  UCMRsEwcN5cXdvqNP-UBup_A
# 1      Pr3g9TPPuH4  UCMRsEwcN5cXdvqNP-UBup_A
# 2      t2TKqJ2FXGM  UCMRsEwcN5cXdvqNP-UBup_A
# 3      8kvb-pJEeEI  UCMRsEwcN5cXdvqNP-UBup_A
# 4      d1QltB3m0Hs  UCMRsEwcN5cXdvqNP-UBup_A
# ...            ...                       ...
# 11200  k63KZROKk1w  UCSzWQmDsKG37iKN2vw1G-2Q
# 11201  mfRIXW9drHo  UCSzWQmDsKG37iKN2vw1G-2Q
# 11202  YDLGZCmO6us  UCSzWQmDsKG37iKN2vw1G-2Q
# 11203  BTyzwZEVJe8  UCSzWQmDsKG37iKN2vw1G-2Q
# 11204  jbgsyvuXfxU  UCSzWQmDsKG37iKN2vw1G-2Q
#
# [11205 rows x 2 columns]
# ----------------------------------------
# Contents of table: Album
#                      id                            title  \
# 0     MPREb_tzu0uaSBSSB                    Back To Black
# 1     MPREb_sQ8U0WxfKar      Black Holes and Revelations
# 2     MPREb_Cb2TQZDVaDj  Sweet Dreams (Are Made Of This)
# 3     MPREb_vDiDlMWN1v0                   Making Mirrors
# 4     MPREb_u6gPLKH7nLh             Take Me to Church EP
# ...                 ...                              ...
# 1540  MPREb_cCrw0VV76Hp     I Love It (Freaky Girl Edit)
# 1541  MPREb_jei9oph58Im                         Thriller
# 1542  MPREb_yNTItzfUtBY                         Thriller
# 1543  MPREb_MEXRqCQVVns                       I AM MUSIC
# 1544  MPREb_WXIqjR5aeEU                 HARDSTONE PSYCHO
#
#                                            thumbnailUrl  year  \
# 0     https://lh3.googleusercontent.com/HxwKiFSKsNLD...  2006
# 1     https://lh3.googleusercontent.com/RcPMBngw0AHz...  2006
# 2     https://lh3.googleusercontent.com/6OEV1ScmH99G...  1983
# 3     https://lh3.googleusercontent.com/baVeQFQOrl0G...  2011
# 4                                                  None  None
# ...                                                 ...   ...
# 1540  https://lh3.googleusercontent.com/6Y9BgF9u6Md9...  2018
# 1541  https://lh3.googleusercontent.com/mz-6kD5E8vON...  2024
# 1542  https://lh3.googleusercontent.com/5b8aT8S_VrFt...  2024
# 1543  https://lh3.googleusercontent.com/NwEB0mlxxOaB...  2024
# 1544  https://lh3.googleusercontent.com/AT0wYoFYZ1K6...  2024
#
#                 authorsText  \
# 0                      2006
# 1                      Muse
# 2                Eurythmics
# 3                     Gotye
# 4                      None
# ...                     ...
# 1540  Kanye West & Lil Pump
# 1541             Gannondorf
# 1542         DB Tha General
# 1543          Playboi Carti
# 1544            Don Toliver
#
#                                                shareUrl     timestamp  \
# 0     https://music.youtube.com/playlist?list=OLAK5u...  1.720737e+12
# 1     https://music.youtube.com/playlist?list=OLAK5u...  1.733937e+12
# 2     https://music.youtube.com/playlist?list=OLAK5u...  1.733937e+12
# 3     https://music.youtube.com/playlist?list=OLAK5u...  1.733937e+12
# 4                                                  None           NaN
# ...                                                 ...           ...
# 1540  https://music.youtube.com/playlist?list=OLAK5u...  1.735343e+12
# 1541  https://music.youtube.com/playlist?list=OLAK5u...  1.735346e+12
# 1542  https://music.youtube.com/playlist?list=OLAK5u...  1.735346e+12
# 1543  https://music.youtube.com/playlist?list=OLAK5u...  1.735411e+12
# 1544  https://music.youtube.com/playlist?list=OLAK5u...  1.735504e+12
#
#       bookmarkedAt
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 1540           NaN
# 1541           NaN
# 1542           NaN
# 1543           NaN
# 1544           NaN
#
# [1545 rows x 8 columns]
# ----------------------------------------
# Contents of table: SongAlbumMap
#            songId            albumId  position
# 0     2G9_5ZQYXVY  MPREb_sQ8U0WxfKar       1.0
# 1     i5_asj1BGFs  MPREb_Cb2TQZDVaDj       5.0
# 2     jg51kFe7CWU  MPREb_vDiDlMWN1v0       2.0
# 3     6A3PMQA5c74  MPREb_u6gPLKH7nLh       NaN
# 4     9PpXu-2fPHc  MPREb_uhwXLl6u86i       2.0
# ...           ...                ...       ...
# 9811  k63KZROKk1w  MPREb_WXIqjR5aeEU      15.0
# 9812  mfRIXW9drHo  MPREb_WXIqjR5aeEU      16.0
# 9813  YDLGZCmO6us  MPREb_WXIqjR5aeEU      17.0
# 9814  BTyzwZEVJe8  MPREb_WXIqjR5aeEU      18.0
# 9815  jbgsyvuXfxU  MPREb_WXIqjR5aeEU      19.0
#
# [9816 rows x 3 columns]
# ----------------------------------------
# Contents of table: SearchQuery
#       id                           query
# 0    299                     teresa teng
# 1    300                           damn.
# 2    304                        oblivion
# 3    307                     frank ocean
# 4    308  mr morale and the big steppers
# ..   ...                             ...
# 224  761                             DS2
# 225  762                          future
# 226  763                        ice cube
# 227  764                         All day
# 228  765                        thriller
#
# [229 rows x 2 columns]
# ----------------------------------------
# Contents of table: QueuedMediaItem
# Empty DataFrame
# Columns: [id, mediaItem, position]
# Index: []
# ----------------------------------------
# Contents of table: Format
#            songId  itag                   mimeType  bitrate  contentLength  \
# 0     rbBbQ-jldvQ   251  audio/webm; codecs="opus"   135821      3842025.0
# 1     Pr3g9TPPuH4   251  audio/webm; codecs="opus"   144088      4269195.0
# 2     t2TKqJ2FXGM   251  audio/webm; codecs="opus"   135381      3468439.0
# 3     8kvb-pJEeEI   251  audio/webm; codecs="opus"   128651      2350437.0
# 4     2G9_5ZQYXVY   251  audio/webm; codecs="opus"   156036      3909289.0
# ...           ...   ...                        ...      ...            ...
# 2791  MFFYMYBK1xI   140                  audio/mp4   131002      2045480.0
# 2792  D2vBuyiJf-0   140                  audio/mp4   131152      2381750.0
# 2793  mfRIXW9drHo   140                  audio/mp4   131054      2877336.0
# 2794  YDLGZCmO6us   140                  audio/mp4   131186      3046516.0
# 2795  BTyzwZEVJe8   140                  audio/mp4   131055      1891861.0
#
#           lastModified  loudnessDb
# 0     1575722104277263    6.599534
# 1     1575714470534165    7.195772
# 2     1575730743161629    7.653587
# 3     1586196175291719    6.351650
# 4     1575377516227129    7.037166
# ...                ...         ...
# 2791  1735348158942924         NaN
# 2792  1719246135848875         NaN
# 2793  1719330182442766         NaN
# 2794  1719330134156102         NaN
# 2795  1719330078904595         NaN
#
# [2796 rows x 7 columns]
# ----------------------------------------
# Contents of table: Event
#           id       songId      timestamp  playTime
# 0          1  rbBbQ-jldvQ  1683257493946    170950
# 1          2  rbBbQ-jldvQ  1683257706634     87147
# 2          3  Pr3g9TPPuH4  1683257963584    256949
# 3          4  t2TKqJ2FXGM  1683258177324    213723
# 4          5  8kvb-pJEeEI  1683258328928    151593
# ...      ...          ...            ...       ...
# 43018  43019  2VPAdf9dkmQ  1735524998389    264362
# 43019  43020  EXmMiBNDVz4  1735525404879    369080
# 43020  43021  EXmMiBNDVz4  1735525404898    369080
# 43021  43022  xcprkHw4cd8  1735525599636    194747
# 43022  43023  xcprkHw4cd8  1735525599667    194747
#
# [43023 rows x 4 columns]
# ----------------------------------------
# Contents of table: Lyrics
#           songId                                              fixed synced
# 0    Q7vTZvUyksE  I ain't get to roll no weed, ain't get to roll...   None
# 1    _GghFQ8ryEU  Pimp-pimp hooray\r\nPimp-pimp hooray\r\nHooray...   None
# 2    inOEtUwSasc  Somebody said you bumped your head and bled th...   None
# 3    jJcd806j7sM  (Denny Cascade)\r\n(Denny Cascade)\r\n(Denny C...   None
# 4    OcKSsXs0FA4  Look, I was gonna go easy on you and not to hu...   None
# ..           ...                                                ...    ...
# 324  Qb7NpEKuEZM  Yeah\r\nFor the first time it's going down in ...   None
# 325  l-Z8PWbAveU  Tell me, is you still up? (Up)\nIt's 5 a.m. an...   None
# 326  3RIgaIW4ww0  I don't know the name of the town you're from\...   None
# 327  NAf8_DMxgtE  So they asked me\r\n"Young boy\r\nWhat you gon...   None
# 328  D2vBuyiJf-0  Sippin' on promethazine\nI'm sippin' on promet...   None
#
# [329 rows x 3 columns]
# ----------------------------------------
# Contents of table: room_master_table
#    id                     identity_hash
# 0  42  205c24811149a247279bcbfdc2d6c396
# ----------------------------------------

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Connect to the SQLite database
connection = sqlite3.connect('../resources/rimusic_20241229182906.db')

# Query the data to get album total listening time
query_time = """
SELECT
    Album.title AS album_title,
    SUM(Event.playTime) AS total_play_time_ms
FROM
    Event
JOIN
    Song ON Event.songId = Song.id
JOIN
    SongAlbumMap ON Song.id = SongAlbumMap.songId
JOIN
    Album ON SongAlbumMap.albumId = Album.id
GROUP BY
    Album.id
ORDER BY
    total_play_time_ms DESC
LIMIT 50;
"""

# Execute the query and fetch the results into a DataFrame
df_time = pd.read_sql_query(query_time, connection)

# Close the database connection
connection.close()

# Convert time from milliseconds to hours for easier readability
df_time['total_play_time_hours'] = df_time['total_play_time_ms'] / (1000 * 60 * 60)

# Plot the data
plt.figure(figsize=(20, 12))
plt.barh(df_time['album_title'], df_time['total_play_time_hours'], color='salmon')
plt.xlabel("Total Play Time (Hours)")
plt.ylabel("Album Title")
plt.title("Top 50 Albums by Total Listening Time")
plt.gca().invert_yaxis()  # Invert y-axis to show the highest at the top
plt.tight_layout()
plt.show()

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Connect to the SQLite database
connection = sqlite3.connect('../resources/rimusic_20241229182906.db')

# Query the data to get album total listening time
query_time = """
SELECT
    Artist.name AS artist_name,
    SUM(Event.playTime) AS total_play_time_ms
FROM
    Event
JOIN
    Song ON Event.songId = Song.id
JOIN
    SongArtistMap ON Song.id = SongArtistMap.songId
JOIN
    Artist ON SongArtistMap.artistId = Artist.id
GROUP BY
    Artist.id
ORDER BY
    total_play_time_ms DESC
LIMIT 50;
"""

# Execute the query and fetch the results into a DataFrame
df_time = pd.read_sql_query(query_time, connection)

# Close the database connection
connection.close()

# Convert time from milliseconds to hours for easier readability
df_time['total_play_time_hours'] = df_time['total_play_time_ms'] / (1000 * 60 * 60)

# Plot the data
plt.figure(figsize=(20, 12))
plt.barh(df_time['artist_name'], df_time['total_play_time_hours'], color='salmon')
plt.xlabel("Total Play Time (Hours)")
plt.ylabel("Album Title")
plt.title("Top 50 Artists by Total Listening Time")
plt.gca().invert_yaxis()  # Invert y-axis to show the highest at the top
plt.tight_layout()
plt.savefig('../out/top50ArtistsAllTime.png')
plt.show()

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Connect to the SQLite database
connection = sqlite3.connect('../resources/rimusic_20241229182906.db')

# Query the data to get album total listening time
query_time = """
SELECT
    Artist.name AS artist_name,
    SUM(Event.playTime) AS total_play_time_ms
FROM
    Event
JOIN
    Song ON Event.songId = Song.id
JOIN
    SongArtistMap ON Song.id = SongArtistMap.songId
JOIN
    Artist ON SongArtistMap.artistId = Artist.id
GROUP BY
    Artist.id
ORDER BY
    total_play_time_ms DESC
LIMIT 50;
"""
def toHexColor(n):
    out = hex(n)[2:];
    zeros = "";
    for i in range(6-len(out)):
        zeros += "0"
    out = "#" + zeros + out;
    return out
colors = range(50)
colors = [toHexColor(0x0000ff + 0x000100*(x*5)) for x in colors]
print(colors)
# Execute the query and fetch the results into a DataFrame
df_time = pd.read_sql_query(query_time, connection)

# Close the database connection
connection.close()

# Convert time from milliseconds to hours for easier readability
df_time['total_play_time_hours'] = df_time['total_play_time_ms'] / (1000 * 60 * 60)

# Plot the data
plt.figure(figsize=(20, 12))
plt.barh(df_time['artist_name'], df_time['total_play_time_hours'], color=colors)
plt.xlabel("Total Play Time (Hours)")
plt.ylabel("Album Title")
plt.title("Top 50 Artists by Total Listening Time")
plt.gca().invert_yaxis()  # Invert y-axis to show the highest at the top
plt.tight_layout()
plt.savefig('../out/top50ArtistsAllTimeBlueGradient.png')
plt.show()
# Out:
# ['#0000ff', '#0005ff', '#000aff', '#000fff', '#0014ff', '#0019ff', '#001eff', '#0023ff', '#0028ff', '#002dff', '#0032ff', '#0037ff', '#003cff', '#0041ff', '#0046ff', '#004bff', '#0050ff', '#0055ff', '#005aff', '#005fff', '#0064ff', '#0069ff', '#006eff', '#0073ff', '#0078ff', '#007dff', '#0082ff', '#0087ff', '#008cff', '#0091ff', '#0096ff', '#009bff', '#00a0ff', '#00a5ff', '#00aaff', '#00afff', '#00b4ff', '#00b9ff', '#00beff', '#00c3ff', '#00c8ff', '#00cdff', '#00d2ff', '#00d7ff', '#00dcff', '#00e1ff', '#00e6ff', '#00ebff', '#00f0ff', '#00f5ff']

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Connect to the SQLite database
connection = sqlite3.connect('../resources/rimusic_20241229182906.db')

# Query the data to get album total listening time
query_time = """
SELECT
    Artist.name AS artist_name,
    SUM(Event.playTime) AS total_play_time_ms
FROM
    Event
JOIN
    Song ON Event.songId = Song.id
JOIN
    SongArtistMap ON Song.id = SongArtistMap.songId
JOIN
    Artist ON SongArtistMap.artistId = Artist.id
GROUP BY
    Artist.id
ORDER BY
    total_play_time_ms DESC
LIMIT 50;
"""
    
bars = None
# Execute the query and fetch the results into a DataFrame
df_time = pd.read_sql_query(query_time, connection)

# Close the database connection
connection.close()

# Convert time from milliseconds to hours for easier readability
df_time['total_play_time_hours'] = df_time['total_play_time_ms'] / (1000 * 60 * 60)
df_time['cumulative_time'] = 0

connection = sqlite3.connect('../resources/rimusic_20241229182906.db')
query_events = """
SELECT
    Artist.name AS artist_name,
    Event.timestamp AS timestamp,
    Event.playtime AS playtime,
    Event.songId as songId
FROM
    Event
JOIN
    Song ON Event.songId = Song.id
JOIN
    SongArtistMap ON Song.id = SongArtistMap.songId
JOIN
    Artist ON SongArtistMap.artistId = Artist.id
"""

df_events = pd.read_sql_query(query_events, connection)
connection.close()

# Initialization function
def init():
    global bars
    bars = ax.bar(df_time['total_play_time_hours'], df_time["artist_name"], color="blue")
    print(bars)
    return bars

# Update function for animation
def update(frame):
    global bars
    ax.clear()
    current_time = df_events["timestamp"].iloc[frame]
    if df_events["artist_name"].iloc[frame] in df_time["artist_name"]:
        df_time.loc[df_events["artist_name"].iloc[frame], "cumulative_time"] += df_events["playtime"].iloc[frame]
    ax.bar(df_time["artist_name"], df_time["cumulative_time"], color="blue")
    ax.set_title(f"Cumulative Listening Times\nUp to {current_time}")
    ax.set_ylabel("Artists")
    ax.set_xlabel("Cumulative Listening Time")
    ax.set_xlim(0, df_time["cumulative_time"].max() + 10)
    return ax.patches

# Create the animation
fig = plt.figure()
ax = plt.subplot()
ax.set_title("Animated Histogram of Cumulative Listening Times")
ax.set_ylabel("Artists")
ax.set_xlabel("Cumulative Listening Time")

ani = FuncAnimation(fig, update, frames=len(df_events), init_func=init, blit=False)
plt.show()
# Out:
# <div id='b37ab998-c9f1-483a-ad51-66057b1c6768'></div>
# /usr/lib/python3/dist-packages/matplotlib/animation.py:889: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you have outputted the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
